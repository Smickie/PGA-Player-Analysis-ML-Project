# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path = os.getcwd()

# %%
df = pd.read_csv(path + "/data/pgaTourData.csv")

# %%
df["Player Name"].nunique()
# Out:
# 526

# %%
len(df)
# Out:
# 2312

# %%
df
# Out:
#              Player Name  Rounds  Fairway Percentage  Year  Avg Distance  \
# 0         Henrik Stenson    60.0               75.19  2018         291.5
# 1            Ryan Armour   109.0               73.58  2018         283.5
# 2            Chez Reavie    93.0               72.24  2018         286.5
# 3             Ryan Moore    78.0               71.94  2018         289.2
# 4           Brian Stuard   103.0               71.44  2018         278.9
# ...                  ...     ...                 ...   ...           ...
# 2307        Carl Paulson     NaN                 NaN  2012           NaN
# 2308      Peter Tomasulo     NaN                 NaN  2012           NaN
# 2309        Marc Turnesa     NaN                 NaN  2010           NaN
# 2310     Jesper Parnevik     NaN                 NaN  2010           NaN
# 2311  Jim Gallagher, Jr.     NaN                 NaN  2010           NaN
#
#         gir  Average Putts  Average Scrambling  Average Score Points  Wins  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2312 entries, 0 to 2311
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Player Name         2312 non-null   object
#  1   Rounds              1678 non-null   float64
#  2   Fairway Percentage  1678 non-null   float64
#  3   Year                2312 non-null   int64
#  4   Avg Distance        1678 non-null   float64
#  5   gir                 1678 non-null   float64
#  6   Average Putts       1678 non-null   float64
#  7   Average Scrambling  1678 non-null   float64
#  8   Average Score       1678 non-null   float64
#  9   Points              2296 non-null   object
#  10  Wins                293 non-null    float64
#  11  Top 10              1458 non-null   float64
#  12  Average SG Putts    1678 non-null   float64
#  13  Average SG Total    1678 non-null   float64
#  14  SG:OTT              1678 non-null   float64
# ...

# %%
temp = df.loc[df["Year"] == 2018]

# %%
temp["Player Name"].nunique()
# Out:
# 261

# %%
temp["Top 10"] = temp["Top 10"].map({np.nan: 0, 1.0: 1, 2.0: 2, 3.0: 3, 4.0: 4, 5.0: 5, 6.0: 6, 7.0: 7, 8.0: 8, 9.0: 9,
                   10.0: 10})
# Out:
# /var/folders/j_/__64n8zj7cl2_v79xs0k7lpm0000gn/T/ipykernel_3100/777849579.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Top 10"] = temp["Top 10"].map({np.nan: 0, 1.0: 1, 2.0: 2, 3.0: 3, 4.0: 4, 5.0: 5, 6.0: 6, 7.0: 7, 8.0: 8, 9.0: 9,

# %%
temp["Top 10"].unique()
# Out:
# array([ 5.,  3.,  6.,  2.,  1., nan,  4.,  8.,  7., 10.])

# %%
temp["Wins"] = temp["Wins"].map({np.nan: 0, 1.0: 1, 2.0: 2, 3.0: 3})
# Out:
# /var/folders/j_/__64n8zj7cl2_v79xs0k7lpm0000gn/T/ipykernel_3100/362988773.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Wins"] = temp["Wins"].map({np.nan: 0, 1.0: 1, 2.0: 2, 3.0: 3})

# %%
temp["Wins"].unique()
# Out:
# array([nan,  1.,  2.,  3.])

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 261 entries, 0 to 1745
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Player Name         261 non-null    object
#  1   Rounds              193 non-null    float64
#  2   Fairway Percentage  193 non-null    float64
#  3   Year                261 non-null    int64
#  4   Avg Distance        193 non-null    float64
#  5   gir                 193 non-null    float64
#  6   Average Putts       193 non-null    float64
#  7   Average Scrambling  193 non-null    float64
#  8   Average Score       193 non-null    float64
#  9   Points              260 non-null    object
#  10  Wins                34 non-null     float64
#  11  Top 10              166 non-null    float64
#  12  Average SG Putts    193 non-null    float64
#  13  Average SG Total    193 non-null    float64
#  14  SG:OTT              193 non-null    float64
# ...

# %%
df["Year"].unique()
# Out:
# array([2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010])

# %%
temp = temp.dropna()

# %%
temp
# Out:
#              Player Name  Rounds  Fairway Percentage  Year  Avg Distance  \
# 0         Henrik Stenson    60.0               75.19  2018         291.5
# 1            Ryan Armour   109.0               73.58  2018         283.5
# 2            Chez Reavie    93.0               72.24  2018         286.5
# 3             Ryan Moore    78.0               71.94  2018         289.2
# 4           Brian Stuard   103.0               71.44  2018         278.9
# ..                   ...     ...                 ...   ...           ...
# 188       Phil Mickelson    90.0               52.91  2018         300.3
# 189           Kevin Tway   110.0               52.61  2018         310.1
# 190  Ollie Schniederjans    91.0               52.22  2018         301.4
# 191     Cameron Tringale    67.0               51.99  2018         289.3
# 192         Ricky Barnes    65.0               47.15  2018         290.6
#
#        gir  Average Putts  Average Scrambling  Average Score Points  Wins  \
# ...

# %%
temp["Money"] = temp["Money"].str.replace("$", "", regex=False)
# Out:
# /var/folders/j_/__64n8zj7cl2_v79xs0k7lpm0000gn/T/ipykernel_3100/4247409633.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Money"] = temp["Money"].str.replace("$", "", regex=False)

# %%
temp["Money"] = temp["Money"].str.replace(",", "", regex=False)
# Out:
# /var/folders/j_/__64n8zj7cl2_v79xs0k7lpm0000gn/T/ipykernel_3100/4029635906.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Money"] = temp["Money"].str.replace(",", "", regex=False)

# %%
temp["Money"] = temp["Money"].astype(int)
# Out:
# /var/folders/j_/__64n8zj7cl2_v79xs0k7lpm0000gn/T/ipykernel_3100/4193369199.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Money"] = temp["Money"].astype(int)

# %%
temp
# Out:
#              Player Name  Rounds  Fairway Percentage  Year  Avg Distance  \
# 0         Henrik Stenson    60.0               75.19  2018         291.5
# 1            Ryan Armour   109.0               73.58  2018         283.5
# 2            Chez Reavie    93.0               72.24  2018         286.5
# 3             Ryan Moore    78.0               71.94  2018         289.2
# 4           Brian Stuard   103.0               71.44  2018         278.9
# ..                   ...     ...                 ...   ...           ...
# 188       Phil Mickelson    90.0               52.91  2018         300.3
# 189           Kevin Tway   110.0               52.61  2018         310.1
# 190  Ollie Schniederjans    91.0               52.22  2018         301.4
# 191     Cameron Tringale    67.0               51.99  2018         289.3
# 192         Ricky Barnes    65.0               47.15  2018         290.6
#
#        gir  Average Putts  Average Scrambling  Average Score Points  Wins  \
# ...

# %%
df.loc[df["Player Name"] == "Tiger Woods"]
# Out:
#       Player Name  Rounds  Fairway Percentage  Year  Avg Distance    gir  \
# 126   Tiger Woods    68.0               59.35  2018         303.6  67.40
# 997   Tiger Woods    61.0               62.50  2013         293.2  67.59
# 1163  Tiger Woods    69.0               63.93  2012         297.4  67.58
# 1882  Tiger Woods     NaN                 NaN  2015           NaN    NaN
# 1989  Tiger Woods     NaN                 NaN  2014           NaN    NaN
# 2171  Tiger Woods     NaN                 NaN  2011           NaN    NaN
# 2250  Tiger Woods     NaN                 NaN  2010           NaN    NaN
#
#       Average Putts  Average Scrambling  Average Score Points  Wins  Top 10  \
# 126           28.49               64.16         69.350  1,162   NaN     5.0
# 997           28.85               60.00         68.944  3,059   5.0     7.0
# 1163          28.91               63.17         68.904  2,269   3.0     6.0
# 1882            NaN                 NaN            NaN    215   NaN     1.0
# ...
